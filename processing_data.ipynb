# %% [markdown]
# # Processing raw data

# %%
import json

# %%
raw_loanwords_file = 'data/raw_loanwords.txt'

loanwords = []
descriptions = []
with open(raw_loanwords_file, 'r') as f:
    lines = f.readlines()
    for line in lines:
        first_space_idx = line.find(' ')
        if first_space_idx != -1:
            loanwords.append(line[:first_space_idx])
            descriptions.append(line[first_space_idx + 1:])

# %%
len(loanwords), len(descriptions)
# Out:
# (862, 862)

# %% [markdown]
# Note that some words are homonyms so we cannot use the words as dict keys, for example:

# %%
for w, v in zip(loanwords[:-1], loanwords[1:]):
    if w == v:
        print(w)
# Out:
# կուզ
# սազ
# սաղ

# %%
armenian_file = 'data/armenian.txt'

def read_lines_from_file(file):
    with open(file, 'r') as f:
        lines = [ws[:-1] for ws in f.readlines()]
    return lines

armenian = read_lines_from_file(armenian_file)

# %%
len(armenian)
# Out:
# 865

# %% [markdown]
# In Armenian words we have filtered the homonyms:

# %%
assert len(set(armenian)) == len(armenian)

# %% [markdown]
# ## Processing syllables

# %%
loanword_syllables_file = 'data/loanword_syllables.txt'
armenian_syllables_file = 'data/armenian_syllables.txt'

loanword_syllables = read_lines_from_file(loanword_syllables_file)
armenian_syllables = read_lines_from_file(armenian_syllables_file)

# %%
def process_syllables(syllable_list):
    syllable_set = set()
    syllable_variants_list = []
    for item in syllable_list:
        variants = item.split('+')
        syllable_variants_list.append(variants)
        for v in variants:
            v_syllables = v.split()
            syllable_set.update(v_syllables)
    return syllable_variants_list, syllable_set

# %%
loanword_syllable_variants, loanword_syllable_set = process_syllables(loanword_syllables)
armenian_syllable_variants, armenian_syllable_set = process_syllables(armenian_syllables)

print(f'{len(loanword_syllable_set)} loanword syllables', list(loanword_syllable_set)[:15], '\n', sep='\n')
print(f'{len(armenian_syllable_set)} Armenian word syllables', list(armenian_syllable_set)[:15], sep='\n')
# Out:
# 828 loanword syllables
# ['րագ', 'պի', 'հու', 'կուշտ', 'մախք', 'չաղ', 'ղե', 'լո', 'րիչ', 'խին', 'աճ', 'զարդ', 'ժոխք', 'քար', 'պ[ը]ս']
#
#
# 795 Armenian word syllables
# ['կաց', 'ցեղ', 'ղե', 'դառ', 'հետք', 'տղել', 'լո', 'սուտ', '[վ]ել', 'նյարդ', 'զարդ', 'ձեղկ', 'քար', 'որթ', 'գուտ']

# %%
def syllables_with_sound(syllables, sound):
    result = []
    for syllable in syllables:
        if sound in syllable:
            result.append(syllable)
    return result

print(f'Loanword syllables with [ը]: {syllables_with_sound(loanword_syllable_set, '[ը]')}\n')
print(f'Armenian word syllables with [ը]: {syllables_with_sound(armenian_syllable_set, '[ը]')}')
# Out:
# Loanword syllables with [ը]: ['պ[ը]ս', 'պ[ը]', 'վ[ը]ս', 'ղ[ը]', 'բ[ը]լ', 'ն[ը]շ', 'ճ[ը]', 'ց[ը]ղ', 'խ[ը]', 'դ[ը]', 'կ[ը]ն', 'մ[ը]', 'կ[ը]ղ', 'թ[ը]շ', 'պ[ը]ղ', 'ն[ը]', 'դ[ը]ժ', 'մ[ը]տ', 'բ[ը]', 'ղ[ը]ս', 'ս[ը]ն', 'վ[ը]', 'ք[ը]', 'զ[ը]խ', 'ն[ը]ժ', 'ս[ը]ռ', 'գ[ը]մ', 'տ[ը]զ', 'շ[ը]ն', 'գ[ը]ր', 'ս[ը]ր', 'ծ[ը]', 'ջ[ը]', 'զ[ը]ն', 'տ[ը]ր', 'տ[ը]', 'կ[ը]ր', 'ճ[ը]ս', 'դ[ը]ր', 'շ[ը]ղ', 'ս[ը]', 'պ[ը]ր', 'զ[ը]մ', 'թ[ը]ր', 'գ[ը]', 'հ[ը]', 'զ[ը]', 'թ[ը]', 'մ[ը]կ', 'թ[ը]զ', 'պ[ը]ն', 'կ[ը]']
#
# Armenian word syllables with [ը]: ['ք[ը]ր', 'ձ[ը]', 'լ[ը]ց', 'պ[ը]', 'մ[ը]ր', 'թ[ը]նկ', 'բ[ը]լ', 'փ[ը]ս', 'փ[ը]', 'լ[ը]', 'թ[ը]ռ', 'փ[ը]ռթ', 'խ[ը]', 'ծ[ը]ն', 'լ[ը]լ', 'պ[ը]լ', 'մ[ը]ռ', 'դ[ը]', 'գ[ը]տ', 'ս[ը]խ', 'դ[ը]ն', 'կ[ը]ն', 'թ[ը]ն', 'մ[ը]', 'կ[ը]ղ', 'պ[ը]ղ', 'ն[ը]', 'թ[ը]մ', 'բ[ը]', 'ջ[ը]ն', 'փ[ը]լ', 'խ[ը]լ', 'լ[ը]ն', 'վ[ը]', 'ք[ը]', 'մ[ը]լ', 'գ[ը]ռ', 'շ[ը]', 'չ[ը]', 'ռ[ը]ն', 'ղ[ը]ր', 'տ[ը]ղ', 'ն[ը]ս', 'տ[ը]զ', 'կ[ը]ս', 'գ[ը]ր', 'ս[ը]ր', 'ծ[ը]', 'ջ[ը]', 'ս[ը]ղ', 'տ[ը]ր', 'կ[ը]մ', 'կ[ը]ր', 'դ[ը]ր', 'փ[ը]ր', 'մ[ը]ղ', 'ս[ը]', 'ծ[ը]պ', 'խ[ը]ն', 'ձ[ը]ր', 'ց[ը]', 'զ[ը]մ', 'թ[ը]ր', 'գ[ը]', 'մ[ը]շ', 'ց[ը]ն', 'փ[ը]ռ', 'հ[ը]', 'զ[ը]', 'թ[ը]', 'մ[ը]ն', 'տ[ը]ն', 'ն[ը]ր', 'կ[ը]']

# %%
# save word-syllables pairs

# loanword_data_file = 'data/loanword_data.json'
# armenian_data_file = 'data/armenian_data.json'

# with open(armenian_data_file, 'r') as f:
#     d = json.load(f)

# for i in range(len(d)):
#     d[i]['syllables'] = armenian_syllable_variants[i]

# d = []
# for w, ws in zip(loanwords, loanword_syllable_variants):
#     d.append({'word': w, 'syllables': ws})

# with open('data/armenian_data1.json', 'w+') as f:
#     json.dump(d, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Processing languages

# %%
def clean_word(w):
    w = w.strip('()՝,.').lower()
    w = w.replace('րէն', 'րեն')
    w = w.replace('ից', '')
    return w

# %%
loanword_langs = []

for i in range(len(loanwords)):
    word = loanwords[i]
    
    items = descriptions[i].split()
    if len(items) == 0:
        print(i, word, descriptions[i])
        continue
    
    loanword_langs.append(set())
    for item in items:
        if 'րեն' in item or 'րէն' in item:
            cleaned = clean_word(item)
            if cleaned in ['պարեն', 'օրենք', 'հաւանօրեն', 'հայերենի']:
                continue
            cleaned_ones = cleaned.split('-')
            loanword_langs[i].update(cleaned_ones)
        else:
            for lang in ['իրանական', 'իրանեան', 'քարթուէլեան', 'սանսկրիտ', 'կովկասեան']:
                if lang in item:
                    cleaned = clean_word(item)
                    loanword_langs[i].add(cleaned)
    
    loanword_langs[i] = list(loanword_langs[i])
    i += 1

# %%
list(zip(loanwords, loanword_langs))
# Out:
# [('աբեղա', ['ասորերեն']),
#  ('ադաթ', ['արաբերեն', 'տաճկերեն']),
#  ('ադամանդ', ['յունարեն']),
#  ('ազապ', ['արաբերեն', 'տաճկերեն']),
#  ('ազատ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ազգ', ['պահլաւերեն']),
#  ('ազիզ', ['տաճկերեն']),
#  ('աժդահա', ['պարսկերեն']),
#  ('աիբ', ['արաբերեն']),
#  ('ալ', ['թուրքերեն']),
#  ('ալամ', ['արաբերեն']),
#  ('ալմաստ', ['պարսկերեն', 'թրքերեն']),
#  ('ալոե', ['յունարեն']),
#  ('ալվան', ['արաբերեն']),
#  ('ախմախ', ['արաբերեն', 'տաճկերեն']),
#  ('ախոռ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ախորժ', ['իրանական']),
#  ('աղա', ['տաճկերեն']),
#  ('աղախին', ['պարսկերեն']),
#  ('աճպարար', ['արաբերեն']),
#  ('աման', ['տաճկերեն']),
#  ('ամբար', ['պարսկերեն', 'պահլաւերեն']),
#  ('ամբարտավան', ['պարսկերեն']),
#  ('ամբոխ', ['պարսկերեն']),
#  ('ամեհի', ['պարսկերեն']),
#  ('ամեն', ['եբրայեցերեն']),
#  ('ամիրա', ['արաբերեն', 'ասորերեն']),
#  ('անագ', ['ասուրերեն', 'սանսկրիտերեն']),
#  ('անանուխ', ['պարսկերեն', 'ասորերեն', 'յունարեն']),
#  ('անապատ', ['պահլաւերեն']),
#  ('անդամ', ['պարսկերեն']),
#  ('անդրի', ['յունարեն']),
#  ('անկյուն', ['յունարեն']),
#  ('անուշ', ['պարսկերեն', 'պահլաւերեն']),
#  ('աշակերտ', ['պարսկերեն']),
#  ('աշխարհ', ['պարսկերեն']),
#  ('աշխետ', ['պարսկերեն', 'պահլաւերեն']),
#  ('աշկարա', ['պարսկերեն']),
#  ('աշտե', ['պարսկերեն']),
#  ('աշուղ', ['արաբերեն', 'տաճկերեն']),
#  ('ապակի', ['պարսկերեն']),
#  ('ապաստան', ['պահլաւերեն']),
#  ('ապատ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ապարանք', ['պարսկերեն']),
#  ('ապսպրանք', ['պահլաւերեն']),
#  ('ապստամբ', ['պահլաւերեն']),
#  ('աջաբսանդալ', ['վրացերեն']),
#  ('առասան', ['պարսկերեն']),
#  ('առատ', ['պարսկերեն', 'պահլաւերեն']),
#  ('
#  ('կամար', ['պարսկերեն', 'յունարեն', 'պահլաւերեն']),
#  ('կայսր', ['յունարեն']),
#  ('կանեփ', ['պարսկերեն', 'յունարեն']),
#  ('կանթեղ', ['յունարեն']),
#  ('կանոն', ['յունարեն']),
#  ('կապալ', ['արաբերեն', 'ռուսերեն', 'տաճկերեն']),
#  ('կապար', ['պարսկերեն', 'ասորերեն']),
#  ('կապիկ', ['պահլաւերեն', 'սանսկրիտերեն']),
#  ('կապիճ', ['պահլաւերեն']),
#  ('կառան', ['արաբերեն']),
#  ('կառք', ['լատիներեն']),
#  ('կարագ', ['պարսկերեն', 'պահլաւերեն']),
#  ('կարմիր', ['եբրայեցերեն', 'պարսկերեն']),
#  ('կացին', ['ասորերեն']),
#  ('կափ', ['պարսկերեն']),
#  ('կեղև', ['ասորերեն']),
#  ('կենտրոն', ['լատիներեն', 'յունարեն']),
#  ('կեռաս', ['յունարեն']),
#  ('կերպ', ['պահլաւերեն']),
#  ('կերպաս', ['պարսկերեն', 'սանսկրիտերեն']),
#  ('կիթառ', ['յունարեն']),
#  ('կիտրոն', ['յունարեն']),
#  ('կիր', ['արաբերեն', 'արամերեն']),
#  ('կիրակի', ['յունարեն']),
#  ('կղմինտր', ['յունարեն']),
#  ('կմախք', ['սումերերեն', 'ասորերեն']),
#  ('կնգուղ', ['լատիներեն', 'յունարեն']),
#  ('կնդրուկ', ['պարսկերեն', 'պահլաւերեն']),
#  ('կնիք', ['ասուրերեն']),
#  ('կշիռ', ['ասուրերեն']),
#  ('կոլորիտ', ['ռուսերեն', 'ֆրանսերեն']),
#  ('կոկորդիլոս', ['յունարեն']),
#  ('կոհակ', ['պահլաւերեն']),
#  ('կողպեք', ['արաբերեն']),
#  ('կոմիտե', ['ռուսերեն', 'ֆրանսերեն']),
#  ('կոնդակ', ['յունարեն']),
#  ('կոնք', ['յունարեն']),
#  ('կոշիկ', ['պարսկերեն', 'պահլաւերեն']),
#  ('կոպալ', ['պարսկերեն']),
#  ('կոտոշ', ['պարսկերեն']),
#  ('կռիվ', ['ասորերեն']),
#  ('կրպակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('կուզ', ['պարսկերեն']),
#  ('կուզ', ['ասորերեն']),
#  ('կուժ', ['պարսկերեն']),
#  ('կույտ', ['պարսկերեն']),
#  ('կույր', ['պարսկերեն', 'պահլաւերեն']),
#  ('կուշտ', ['պարսկերեն']),
#  ('կուպր', ['ասուրերեն']),
#  ('կոշիկ', ['պարսկերեն', 'պահլաւերեն']),
#  ('հաբ', ['արաբերեն']),
#  ('հազար', ['պարսկերեն']),
#  ('հալ', ['արաբերեն', 'տաճկերեն']),
#  ('հալալ', ['արաբերեն', 'տաճկերեն']),
#  ('հալվա', ['արաբերեն', 'տաճկերեն']),
#  ('հախ', ['արաբերեն', 'տաճկերեն']),
#  ('հակինթ', ['յունարեն']),
#  ('համադամ', ['պարսկերեն']),
#  ('համակ', ['պարսկերեն', 'պահլաւերեն']),
#  
', ['պարսկերեն', 'պահլաւերեն']),
#  ('ճաղ', ['վրացերեն']),
#  ('ճամբար', ['պարսկերեն', 'պահլաւերեն']),
#  ('ճանկ', ['պարսկերեն']),
#  ('ճաշ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ճաշակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ճատրակ', ['արաբերեն', 'պահլաւերեն', 'սանսկրիտերեն']),
#  ('ճար', ['պարսկերեն']),
#  ('ճարպ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ճարտար', ['պարսկերեն']),
#  ('ճեմ', ['պարսկերեն']),
#  ('ճիպոտ', ['ասուրերեն', 'ասորերեն']),
#  ('ճիտ', ['արաբերեն']),
#  ('ճկույթ', ['լազերեն']),
#  ('ճստիկ', ['պարսկերեն']),
#  ('ճրագ', ['պարսկերեն']),
#  ('մագաղաթ', ['ասորերեն']),
#  ('մագիստրոս', ['յունարեն']),
#  ('մալ', ['արաբերեն']),
#  ('մալուխ', ['ասուրերեն']),
#  ('մախմուր', ['տաճկերեն']),
#  ('մակույկ', ['պարսկերեն']),
#  ('մահտեսի', ['արաբերեն']),
#  ('մաղարիչ', ['ռուսերեն']),
#  ('մայլա', ['արաբերեն']),
#  ('մանդատ', ['ռուսերեն', 'ֆրանսերեն']),
#  ('մանղալ', ['տաճկերեն']),
#  ('մանյակ', ['յունարեն']),
#  ('մաշկ', ['ասորերեն']),
#  ('մառան', ['պարսկերեն', 'ասորերեն']),
#  ('մասլահաթ', ['արաբերեն', 'տաճկերեն']),
#  ('մատակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('մատիտ', ['իտալերեն']),
#  ('մատյան', ['պարսկերեն', 'պահլաւերեն']),
#  ('մատուռ', ['յունարեն']),
#  ('մարգ', ['պարսկերեն']),
#  ('մարգարե', ['սոգդիարեն', 'պահլաւերեն']),
#  ('մարգարիտ', ['լատիներեն', 'յունարեն']),
#  ('մարզ', ['պահլաւերեն']),
#  ('մարմար', ['յունարեն']),
#  ('մարտիրոս', ['յունարեն']),
#  ('մելան', ['յունարեն']),
#  ('մելիք', ['արաբերեն']),
#  ('մեխ', ['պարսկերեն']),
#  ('մեռոն', ['յունարեն']),
#  ('մետաղ', ['յունարեն']),
#  ('մետաքս', ['ասորերեն', 'յունարեն']),
#  ('մեյդան', ['արաբերեն']),
#  ('մկրատ', ['արաբերեն']),
#  ('միմոս', ['յունարեն']),
#  ('մշակ', ['լազերեն', 'վրացերեն', 'ինգուշերեն']),
#  ('մոգ', ['պարսկերեն', 'պահլաւերեն']),
#  ('մոմ', ['պարսկերեն', 'պահլաւերեն']),
#  ('մտրակ', ['ասորերեն']),
#  ('մունետիկ', ['արաբերեն']),
#  ('մուռտառ', ['պարսկերեն']),
#  ('մուրազ', ['արաբերեն', 'տաճկերեն']),
#  ('մուրհակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('մուֆտա', ['արաբերեն']),
#  ('յախշի', ['թուրքերեն']),
#  ('յայլա', ['տաճկերեն']),
#  ('յարա', ['տաճկերեն']),
#  ('յորղան', ['թուրքերեն']),
#  ('նազ', ['պարսկերեն']),
#  ('նազիր', ['արաբերեն']),
#  ('նաժիշտ', ['պարսկերեն']),
#  ('նալ', ['արաբերեն', 'տաճկերեն']),
#  ('նալբանդ', ['պարսկերեն']),
#  ('նախ', ['պարսկերեն', 'պահլաւերեն']),
#  ('նախարար', ['սոգդիարեն', 'իրանական']),
#  ('նահանգ', ['ասուրերեն']),
#  ('նահանջ', ['պարսկերեն', 'պահլաւերեն']),
#  ('նահատակ', ['զենդերեն', 'պահլաւերեն']),
#  ('նաղդ', ['արաբերեն']),
#  ('նամակ', ['պարսկերեն', 'պահլաւերեն']),
#  
', ['պարսկերեն', 'պահլաւերեն']),
#  ('սուրհանդակ', ['պարսկերեն']),
#  ('սուրմա', ['պարսկերեն']),
#  ('սուս', ['տաճկերեն']),
#  ('սուսեր', ['ասորերեն', 'պահլաւերեն']),
#  ('վագր', ['պահլաւերեն', 'սանսկրիտերեն']),
#  ('վախտ', ['արաբերեն', 'տաճկերեն']),
#  ('վաճառ', ['պարսկերեն', 'պահլաւերեն']),
#  ('վանդակ', ['պահլաւերեն']),
#  ('վանք', ['սանսկրիտ']),
#  ('վաշխ', ['պարսկերեն']),
#  ('վաշտ', ['պահլաւերեն']),
#  ('վառոդ', ['տաճկերեն']),
#  ('վավեր', ['պարսկերեն', 'պահլաւերեն']),
#  ('վատ', ['պարսկերեն', 'պահլաւերեն']),
#  ('վատթար', ['պարսկերեն', 'պահլաւերեն']),
#  ('վարազ', ['պարսկերեն', 'պահլաւերեն']),
#  ('վարդ', ['պահլաւերեն']),
#  ('վարդապետ', ['պահլաւերեն']),
#  ('վարժ', ['պարսկերեն', 'պահլաւերեն']),
#  ('վարս', ['պահլաւերեն']),
#  ('վարտիք', ['պահլաւերեն']),
#  ('վարուժան', ['պարսկերեն']),
#  ('վեզիր', ['արաբերեն', 'տաճկերեն']),
#  ('վեհ', ['պարսկերեն', 'պահլաւերեն']),
#  ('վեղար', ['լատիներեն', 'յունարեն']),
#  ('վիճակ', ['պահլաւերեն']),
#  ('վին', ['պահլաւերեն', 'սանսկրիտերեն']),
#  ('վիշտ', ['պահլաւերեն', 'սանսկրիտերեն']),
#  ('վկա', ['զենդերեն', 'պահլաւերեն']),
#  ('վճար', ['պահլաւերեն']),
#  ('վճիռ', ['պահլաւերեն']),
#  ('վստահ', ['պահլաւերեն']),
#  ('տախտակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տակառ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տաղանդ', ['յունարեն']),
#  ('տաճար', ['պարսկերեն']),
#  ('տապ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տապան', ['պարսկերեն']),
#  ('տապար', ['պարսկերեն', 'պահլաւերեն']),
#  ('տավիղ', ['պահլաւերեն']),
#  ('տարա', ['արաբերեն', 'իտալերեն']),
#  ('տարազ', ['պարսկերեն', 'պահլաւերեն', 'արաբերեն']),
#  ('տափ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տեգ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տետր', ['յունարեն']),
#  ('տզրուկ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տիպ', ['յունարեն']),
#  ('տիտան', ['յունարեն']),
#  ('տիտղոս', ['յունարեն']),
#  ('տղա', ['ասորերեն']),
#  ('տնազ', ['արաբերեն']),
#  ('տոթ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տոկոս', ['յունարեն']),
#  ('տոհմ', ['պարսկերեն', 'պահլաւերեն']),
#  ('տոմար', ['յունարեն']),
#  ('տոպրակ', ['թաթարերեն']),
#  ('տույժ', ['պահլաւերեն']),
#  ('րոպե', ['յունարեն']),
#  ('ցեխ', ['ռուսերեն', 'գերմաներեն']),
#  ('ուխտ', ['զենդերեն', 'պահլաւերեն']),
#  ('ուղտ', ['ասուրերեն', 'իրանական']),
#  ('ուժ', ['պահլաւերեն']),
#  ('ուշ', ['պարսկերեն', 'պահլաւերեն']),
#  ('ուստա', ['պարսկերեն', 'տաճկերեն']),
#  ('ուրագ', ['ասուրերեն']),
#  ('փալան', ['պարսկերեն']),
#  ('փահլևան', ['պարսկերեն']),
#  ('փաղանգ', ['յունարեն']),
#  ('փայ', ['տաճկերեն']),
#  ('փանջարա', ['պարսկերեն']),
#  ('փաշա', ['տաճկերեն']),
#  ('փառք', ['պարսկերեն', 'պահլաւերեն']),
#  ('փաստ', ['լատիներեն']),
#  ('փարախ', ['կովկասեան', 'վրացերեն']),
#  ('փարաջա', ['տաճկերեն']),
#  ('փարատ', ['ասորերեն']),
#  ('փարթամ', ['պարսկերեն', 'պահլաւերեն']),
#  ('փեթակ', ['պահլաւերեն', 'սանսկրիտերեն']),
#  ('փեշ', ['պարսկերեն']),
#  ('փեշակ', ['պարսկերեն']),
#  ('փեշքեշ', ['պարսկերեն']),
#  ('փերեզակ', ['պարսկերեն']),
#  ('փերի', ['պարսկերեն', 'զենդերեն', 'սոգդիարեն', 'պահլաւերեն']),
#  ('փիղ', ['պարսկերեն', 'պահլաւերեն']),
#  ('փիս', ['տաճկերեն']),
#  ('փոխինդ', ['լատիներեն']),
#  ('փող', ['պարսկերեն']),
#  ('փոշման', ['պարսկերեն', 'տաճկերեն']),
#  ('փոս', ['լատիներեն', 'յունարեն']),
#  ('փոցղ', ['վրացերեն']),
#  ('փուչ', ['պարսկերեն']),
#  ('քած', ['կովկասեան']),
#  ('քահանա', ['արամերեն', 'ասորերեն']),
#  ('քաղաք', ['ասուրերեն']),
#  ('քամանչա', ['պարսկերեն']),
#  ('քաչալ', ['պարսկերեն']),
#  ('քարավան', ['պարսկերեն', 'պահլաւերեն']),
#  ('քարոզ', ['ասորերեն']),
#  ('քարտեզ', ['յունարեն']),
#  ('քարտուղար', ['յունարեն']),
#  ('քեֆ', ['արաբերեն', 'տաճկերեն']),
#  ('քիչ', ['պարսկերեն']),
#  ('քլունգ', ['տաճկերեն']),
#  ('քյանդրբազ', ['ադրբեջաներեն']),
#  ('քնար', ['ասորերեն']),
#  ('քսակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('քվե', ['արամերեն', 'յունարեն']),
#  ('քունջութ', ['պարսկերեն', 'պահլաւերեն']),
#  ('քուչա', ['պարսկերեն']),
#  ('քուռակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('քուրձ', ['ասորերեն', 'պահլաւերեն']),
#  ('քուրմ', ['ասորերեն']),
#  ('օյին', ['տաճկերեն']),
#  ('օշարակ', ['պարսկերեն', 'պահլաւերեն']),
#  ('օրինակ', ['պահլաւերեն']),
#  ('օրհնել', ['պարսկերեն', 'պահլաւերեն']),
#  ('ֆիդայի', ['պարսկերեն']),
#  ('ֆիզիկա', ['լատիներեն', 'յունարեն'])]

# %%
# lines containing neither 'րեն' and 'րէն'
for i, (w, wl) in enumerate(zip(loanwords, loanword_langs)):
    if wl == []:
        print(i, w, descriptions[i][:-1], sep='\t')

# original output
# 16	ախորժ	(իրանական ✽ a-xuarza, xuarzist, քաղցրագոյն)
# 63	ատրճանակ	(իրանական aturġanak)
# 64	ատրուշան	(իրանեան atur և ?) - զոհասեղան
# 98	բավ	(իրանական bav, զօրեղ, առատ լինել՝ կարող լինել)
# 299	ժանտ	(իրանեան ✽ žant, հոտ, վատ հոտ)
# 603	ոչխար	(քարթուէլեան լեզուներից, սկզբնական նշանակութեամբ՝ կենդանի)
# 655	պարմանի	(իրանեան ծագում ?)
# 751	վանք	(սանսկրիտ vanc, տուն)
# 834	քած	(կովկասեան լեզուներից)

# %%
def lang_set(lang_lists):
    lang_set = set()
    for ls in lang_lists:
        lang_set.update(ls)
    return lang_set

langs = lang_set(loanword_langs)
print(langs)
# Out:
# {'բուլգարերեն', 'գերմաներեն', 'ույղուրերեն', 'սանսկրիտ', 'կովկասեան', 'սանսկրիտերեն', 'զանդկերեն', 'տաճկերեն', 'զենտերեն', 'նախահայերեն', 'ֆրանսերեն', 'պարսկերեն', 'եբրայեցերեն', 'թրքերեն', 'խալդերեն', 'պահլաւերեն', 'իրանական', 'պազենդերեն', 'արամերեն', 'պարթևերեն', 'թաթարերեն', 'իրանեան', 'ռուսերեն', 'իտալերեն', 'սումերերեն', 'փռիւգերեն', 'վրացերեն', 'ադրբեջաներեն', 'թիպեթերեն', 'արաբերեն', 'զենդերեն․', 'լազերեն', 'քարթուէլեան', 'ասորերեն', 'լատիներեն', 'քրդերեն', 'յունարեն', 'հունարեն', 'բաբելացերեն', 'թիբետերեն', 'ասուրերեն', 'զենդերեն', 'թուրքերեն', 'սոգդիարեն', 'ինգուշերեն'}

# %%
len(langs)
# Out:
# 45

# %%
lang_replace_dict = {
    'ադրբեջաներեն': 'ադրբեջաներեն',
    'ասորերեն': 'ասորերեն',
    'ասուրերեն': 'ասորերեն',
    'արաբերեն': 'արաբերեն',
    'արամերեն': 'արամերեն',
    'բաբելացերեն': 'բաբելացերեն',
    'բուլգարերեն': 'բուլղարերեն',
    'գերմաներեն': 'գերմաներեն',
    'եբրայեցերեն': 'եբրայերեն',
    'զանդկերեն': 'զենդերեն',
    'զենդերեն': 'զենդերեն',
    'զենդերեն․': 'զենդերեն',
    'զենտերեն': 'զենդերեն',
    'թաթարերեն': 'թաթարերեն',
    'թիբետերեն': 'տիբեթերեն',
    'թիպեթերեն': 'տիբեթերեն',
    'թուրքերեն': 'թուրքերեն',
    'թրքերեն': 'թուրքերեն',
    'ինգուշերեն': 'ինգուշերեն',
    'իտալերեն': 'իտալերեն',
    'իրանական': 'իրանական',
    'իրանեան': 'իրանական',
    'լազերեն': 'լազերեն',
    'լատիներեն': 'լատիներեն',
    'խալդերեն': 'խալդերեն',
    'կովկասեան': 'կովկասյան',
    'հունարեն': 'հունարեն',
    'յունարեն': 'հունարեն',
    'նախահայերեն': 'նախահայերեն',
    'ույղուրերեն': 'ույղուրերեն',
    'պազենդերեն': 'պազենդերեն',
    'պահլաւերեն': 'պահլավերեն',
    'պարթևերեն': 'պարթևերեն',
    'պարսկերեն': 'պարսկերեն',
    'ռուսերեն': 'ռուսերեն',
    'սանսկրիտ': 'սանսկրիտերեն',
    'սանսկրիտերեն': 'սանսկրիտերեն',
    'սոգդիարեն': 'սոգդիարեն',
    'սումերերեն': 'շումերերեն',
    'վրացերեն': 'վրացերեն',
    'տաճկերեն': 'տաճկերեն',
    'փռիւգերեն': 'փռյուգերեն',
    'քարթուէլեան': 'քարթվելյան',
    'քրդերեն': 'քրդերեն',
    'ֆրանսերեն': 'ֆրանսերեն'
}

# %%
for wl in loanword_langs:
    for i in range(len(wl)):
        wl[i] = lang_replace_dict[wl[i]]
    wl = list(set(wl))

# %%
langs = lang_set(loanword_langs)
print(langs)
# Out:
# {'շումերերեն', 'գերմաներեն', 'ույղուրերեն', 'քարթվելյան', 'սանսկրիտերեն', 'բուլղարերեն', 'կովկասյան', 'տաճկերեն', 'նախահայերեն', 'ֆրանսերեն', 'պարսկերեն', 'եբրայերեն', 'խալդերեն', 'փռյուգերեն', 'իրանական', 'պազենդերեն', 'պահլավերեն', 'արամերեն', 'պարթևերեն', 'թաթարերեն', 'ռուսերեն', 'տիբեթերեն', 'իտալերեն', 'վրացերեն', 'ադրբեջաներեն', 'արաբերեն', 'լազերեն', 'ասորերեն', 'հունարեն', 'լատիներեն', 'քրդերեն', 'բաբելացերեն', 'զենդերեն', 'թուրքերեն', 'սոգդիարեն', 'ինգուշերեն'}

# %%
len(langs)
# Out:
# 36

# %%
lang_counts = {lang: 0 for lang in langs}

for wl in loanword_langs:
    for lang in wl:
        lang_counts[lang] += 1

# %%
dict(sorted(lang_counts.items(), key=lambda item: -item[1]))
# Out:
# {'պարսկերեն': 361,
#  'պահլավերեն': 222,
#  'տաճկերեն': 118,
#  'արաբերեն': 111,
#  'հունարեն': 97,
#  'ասորերեն': 75,
#  'զենդերեն': 36,
#  'թուրքերեն': 19,
#  'վրացերեն': 14,
#  'լատիներեն': 14,
#  'ռուսերեն': 13,
#  'սանսկրիտերեն': 12,
#  'իրանական': 12,
#  'ֆրանսերեն': 10,
#  'եբրայերեն': 9,
#  'քրդերեն': 6,
#  'թաթարերեն': 5,
#  'սոգդիարեն': 5,
#  'արամերեն': 4,
#  'գերմաներեն': 3,
#  'պազենդերեն': 3,
#  'իտալերեն': 3,
#  'ադրբեջաներեն': 3,
#  'կովկասյան': 2,
#  'տիբեթերեն': 2,
#  'լազերեն': 2,
#  'բաբելացերեն': 2,
#  'շումերերեն': 1,
#  'ույղուրերեն': 1,
#  'քարթվելյան': 1,
#  'բուլղարերեն': 1,
#  'նախահայերեն': 1,
#  'խալդերեն': 1,
#  'փռյուգերեն': 1,
#  'պարթևերեն': 1,
#  'ինգուշերեն': 1}

# %%
# save word-syllables-langs triples

# loanword_data_file = 'data/loanword_data.json'

# with open('data/loanword_data.json', 'r') as f:
#     d = json.load(f)

# for i in range(len(d)):
#     d[i]['langs'] = word_langs[i]

# with open('data/loanword_data.json', 'w+') as f:
#     json.dump(d, f, indent=4, ensure_ascii=False)
